# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import boto3
import pandas as pd; pd.set_option('display.max_columns', 200)
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from Help_Funs import count_chars, count_words, count_capital_chars, count_capital_words, count_sent, count_unique_words, count_stopwords, count_hashtags 

s3 = boto3.resource('s3')
bucket_name = 'analytics-data-science-competitions'
bucket = s3.Bucket(bucket_name)

## Defining files names
file_key_1 = 'NLP-Disaster-Tweets/train.csv'
file_key_2 = 'NLP-Disaster-Tweets/test.csv'
file_key_3 = 'NLP-Disaster-Tweets/sample_submission.csv'

bucket_object_1 = bucket.Object(file_key_1)
file_object_1 = bucket_object_1.get()
file_content_stream_1 = file_object_1.get('Body')

bucket_object_2 = bucket.Object(file_key_2)
file_object_2 = bucket_object_2.get()
file_content_stream_2 = file_object_2.get('Body')

bucket_object_3 = bucket.Object(file_key_3)
file_object_3 = bucket_object_3.get()
file_content_stream_3 = file_object_3.get('Body')

## Reading data-files
train = pd.read_csv(file_content_stream_1)
test = pd.read_csv(file_content_stream_2)
sample = pd.read_csv(file_content_stream_3)

# %% [markdown]
# # Basic Exploration

# %%
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train['text'][40]
# Out:
# 'Check these out: http://t.co/rOI2NSmEJJ http://t.co/3Tj8ZjiN21 http://t.co/YDUiXEfIpE http://t.co/LxTjc87KLS #nsfw'

# %%
train.loc[40]
# Out:
# keyword                                                          ablaze
# text                  Check these out: http://t.co/rOI2NSmEJJ http:/...
# target                                                                0
# char_count                                                          114
# word_count                                                            8
# sent_count                                                            1
# capital_char_count                                                   23
# capital_word_count                                                    0
# stopword_count                                                        2
# unique_word_count                                                     8
# avg_wordlength                                                    14.25
# avg_sentlength                                                      8.0
# unique_vs_words                                                     1.0
# stopwords_vs_words                                                 0.25
# Name: 40, dtype: object

# %%
train['target'].value_counts() / train.shape[0]
# Out:
# 0    0.57034
# 1    0.42966
# Name: target, dtype: float64

# %%
train['keyword'].value_counts()
# Out:
# fatalities               45
# deluge                   42
# armageddon               42
# sinking                  41
# damage                   41
#                          ..
# forest%20fire            19
# epicentre                12
# threat                   11
# inundation               10
# radiation%20emergency     9
# Name: keyword, Length: 221, dtype: int64

# %%
test['keyword'].value_counts()
# Out:
# deluged               23
# demolished            22
# rubble                22
# first%20responders    21
# seismic               21
#                       ..
# threat                 5
# fatalities             5
# forest%20fire          5
# inundation             4
# epicentre              1
# Name: keyword, Length: 221, dtype: int64

# %%
np.isin(test['keyword'].unique(), train['keyword'].unique())
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
test['keyword'].unique()
# Out:
# array([nan, 'ablaze', 'accident', 'aftershock', 'airplane%20accident',
#        'ambulance', 'annihilated', 'annihilation', 'apocalypse',
#        'armageddon', 'army', 'arson', 'arsonist', 'attack', 'attacked',
#        'avalanche', 'battle', 'bioterror', 'bioterrorism', 'blaze',
#        'blazing', 'bleeding', 'blew%20up', 'blight', 'blizzard', 'blood',
#        'bloody', 'blown%20up', 'body%20bag', 'body%20bagging',
#        'body%20bags', 'bomb', 'bombed', 'bombing', 'bridge%20collapse',
#        'buildings%20burning', 'buildings%20on%20fire', 'burned',
#        'burning', 'burning%20buildings', 'bush%20fires', 'casualties',
#        'casualty', 'catastrophe', 'catastrophic', 'chemical%20emergency',
#        'cliff%20fall', 'collapse', 'collapsed', 'collide', 'collided',
#        'collision', 'crash', 'crashed', 'crush', 'crushed', 'curfew',
#        'cyclone', 'damage', 'danger', 'dead', 'death', 'deaths', 'debris',
#        'deluge', 'deluged', 'demolish', 'demolished', 'demolition',
#        'derail', 'derailed', 'derailment', 'desolate', 'desolation',
#        'destroy', 'destroyed', 'destruction', 'detonate', 'detonation',
#        'devastated', 'devastation', 'disaster', 'displaced', 'drought',
#        'drown', 'drowned', 'drowning', 'dust%20storm', 'earthquake',
#        'electrocute', 'electrocuted', 'emergency', 'emergency%20plan',
#        'emergency%20services', 'engulfed', 'epicentre', 'evacuate',
#        'evacuated', 'evacuation', 'explode', 'exploded', 'explosion',
#        'eyewitness', 'famine', 'fatal', 'fatalities', 'fatality', 'fear',
#        'fire', 'fire%20truck', 'first%20responders', 'flames',
#        'flattened', 'flood', 'flooding', 'floods', 'forest%20fire',
#        'forest%20fires', 'hail', 'hailstorm', 'harm', 'hazard',
#        'hazardous', 'heat%20wave', 'hellfire', 'hijack', 'hijacker',
#        'hijacking', 'hostage', 'hostages', 'hurricane', 'injured',
#        'injuries', 'injury', 'inundated', 'inundation', 'landslide',
#        'lava', 'lightning', 'loud%20bang', 'mass%20murder',
#        'mass%20murderer', 'massacre', 'mayhem', 'meltdown', 'military',
#        'mudslide', 'natural%20disaster', 'nuclear%20disaster',
#        'nuclear%20reactor', 'obliterate', 'obliterated', 'obliteration',
#        'oil%20spill', 'outbreak', 'pandemonium', 'panic', 'panicking',
#        'police', 'quarantine', 'quarantined', 'radiation%20emergency',
#        'rainstorm', 'razed', 'refugees', 'rescue', 'rescued', 'rescuers',
#        'riot', 'rioting', 'rubble', 'ruin', 'sandstorm', 'screamed',
#        'screaming', 'screams', 'seismic', 'sinkhole', 'sinking', 'siren',
#        'sirens', 'smoke', 'snowstorm', 'storm', 'stretcher',
#        'structural%20failure', 'suicide%20bomb', 'suicide%20bomber',
#        'suicide%20bombing', 'sunk', 'survive', 'survived', 'survivors',
#        'terrorism', 'terrorist', 'threat', 'thunder', 'thunderstorm',
#        'tornado', 'tragedy', 'trapped', 'trauma', 'traumatised',
#        'trouble', 'tsunami', 'twister', 'typhoon', 'upheaval',
#        'violent%20storm', 'volcano', 'war%20zone', 'weapon', 'weapons',
#        'whirlwind', 'wild%20fires', 'wildfire', 'windstorm', 'wounded',
#        'wounds', 'wreck', 'wreckage', 'wrecked'], dtype=object)

# %%
train['keyword'].unique()
# Out:
# array([nan, 'ablaze', 'accident', 'aftershock', 'airplane%20accident',
#        'ambulance', 'annihilated', 'annihilation', 'apocalypse',
#        'armageddon', 'army', 'arson', 'arsonist', 'attack', 'attacked',
#        'avalanche', 'battle', 'bioterror', 'bioterrorism', 'blaze',
#        'blazing', 'bleeding', 'blew%20up', 'blight', 'blizzard', 'blood',
#        'bloody', 'blown%20up', 'body%20bag', 'body%20bagging',
#        'body%20bags', 'bomb', 'bombed', 'bombing', 'bridge%20collapse',
#        'buildings%20burning', 'buildings%20on%20fire', 'burned',
#        'burning', 'burning%20buildings', 'bush%20fires', 'casualties',
#        'casualty', 'catastrophe', 'catastrophic', 'chemical%20emergency',
#        'cliff%20fall', 'collapse', 'collapsed', 'collide', 'collided',
#        'collision', 'crash', 'crashed', 'crush', 'crushed', 'curfew',
#        'cyclone', 'damage', 'danger', 'dead', 'death', 'deaths', 'debris',
#        'deluge', 'deluged', 'demolish', 'demolished', 'demolition',
#        'derail', 'derailed', 'derailment', 'desolate', 'desolation',
#        'destroy', 'destroyed', 'destruction', 'detonate', 'detonation',
#        'devastated', 'devastation', 'disaster', 'displaced', 'drought',
#        'drown', 'drowned', 'drowning', 'dust%20storm', 'earthquake',
#        'electrocute', 'electrocuted', 'emergency', 'emergency%20plan',
#        'emergency%20services', 'engulfed', 'epicentre', 'evacuate',
#        'evacuated', 'evacuation', 'explode', 'exploded', 'explosion',
#        'eyewitness', 'famine', 'fatal', 'fatalities', 'fatality', 'fear',
#        'fire', 'fire%20truck', 'first%20responders', 'flames',
#        'flattened', 'flood', 'flooding', 'floods', 'forest%20fire',
#        'forest%20fires', 'hail', 'hailstorm', 'harm', 'hazard',
#        'hazardous', 'heat%20wave', 'hellfire', 'hijack', 'hijacker',
#        'hijacking', 'hostage', 'hostages', 'hurricane', 'injured',
#        'injuries', 'injury', 'inundated', 'inundation', 'landslide',
#        'lava', 'lightning', 'loud%20bang', 'mass%20murder',
#        'mass%20murderer', 'massacre', 'mayhem', 'meltdown', 'military',
#        'mudslide', 'natural%20disaster', 'nuclear%20disaster',
#        'nuclear%20reactor', 'obliterate', 'obliterated', 'obliteration',
#        'oil%20spill', 'outbreak', 'pandemonium', 'panic', 'panicking',
#        'police', 'quarantine', 'quarantined', 'radiation%20emergency',
#        'rainstorm', 'razed', 'refugees', 'rescue', 'rescued', 'rescuers',
#        'riot', 'rioting', 'rubble', 'ruin', 'sandstorm', 'screamed',
#        'screaming', 'screams', 'seismic', 'sinkhole', 'sinking', 'siren',
#        'sirens', 'smoke', 'snowstorm', 'storm', 'stretcher',
#        'structural%20failure', 'suicide%20bomb', 'suicide%20bomber',
#        'suicide%20bombing', 'sunk', 'survive', 'survived', 'survivors',
#        'terrorism', 'terrorist', 'threat', 'thunder', 'thunderstorm',
#        'tornado', 'tragedy', 'trapped', 'trauma', 'traumatised',
#        'trouble', 'tsunami', 'twister', 'typhoon', 'upheaval',
#        'violent%20storm', 'volcano', 'war%20zone', 'weapon', 'weapons',
#        'whirlwind', 'wild%20fires', 'wildfire', 'windstorm', 'wounded',
#        'wounds', 'wreck', 'wreckage', 'wrecked'], dtype=object)

# %%
train['location'] = np.where(train['location'] == 'United States', 'USA', train['location'])
train['location'] = np.where(train['location'] == 'US', 'USA', train['location'])

# %%
train['location'].value_counts()
# Out:
# USA                    104
# New York                71
# United States           50
# London                  45
# Canada                  29
#                       ...
# MontrÌ©al, QuÌ©bec       1
# Montreal                 1
# ÌÏT: 6.4682,3.18287      1
# Live4Heed??              1
# Lincoln                  1
# Name: location, Length: 3341, dtype: int64

# %%
train.shape
# Out:
# (7613, 14)

# %%
train['location'].unique().tolist()
# Out:
# [nan,
#  'Birmingham',
#  'Est. September 2012 - Bristol',
#  'AFRICA',
#  'Philadelphia, PA',
#  'London, UK',
#  'Pretoria',
#  'World Wide!!',
#  'Paranaque City',
#  'Live On Webcam',
#  'milky way',
#  'GREENSBORO,NORTH CAROLINA',
#  'England.',
#  'Sheffield Township, Ohio',
#  'India',
#  'Barbados',
#  'Anaheim',
#  'Abuja',
#  'USA',
#  'South Africa',
#  'Sao Paulo, Brazil',
#  'hollywoodland ',
#  'Edmonton, Alberta - Treaty 6',
#  'Inang Pamantasan',
#  'Twitter Lockout in progress',
#  'Concord, CA',
#  'Calgary, AB',
#  'San Francisco',
#  'CLVLND',
#  'Nashville, TN',
#  'Santa Clara, CA',
#  'UK',
#  'St. Louis, MO',
#  'Walker County, Alabama',
#  'Australia',
#  'North Carolina',
#  'Norf Carolina',
#  'San Mateo County, CA',
#  'Njoro, Kenya',
#  "Your Sister's Bedroom",
#  'Arlington, TX',
#  'South Bloomfield, OH',
#  'New Hanover County, NC',
#  'Maldives',
#  'Manchester, NH',
#  'Wilmington, NC',
#  'global',
#  'Alberta | Sask. | Montana',
#  'Charlotte',
#  'Baton Rouge, LA',
#  'Hagerstown, MD',
#  'Gloucestershire , UK',
#  'Nairobi, Kenya',
#  'Instagram - @heyimginog ',
#  '304',
#  'Switzerland',
#  'US',
#  'Somewhere Only We Know ?',
#  'Belgium',
#  'dope show',
#  'Oshawa, Canada',
#  'Baker City Oregon',
#  'United States',
#  'marysville ca ',
#  'Hermosa Beach, CA',
#  '19.600858, -99.047821',
#  'Pennsylvania',
#  'Salt Lake City, Utah',
#  'Palo Alto, CA',
#  'Spain but Opa-Locka, FL',
#  'Jaipur, India',
#  'Hyderabad Telangana INDIA',
#  'Eagle Pass, Texas',
#  'bangalore',
#  'Financial News and Views',
#  'Indonesia',
#  'y(our) boyfriends legs ',
#  'New Mexico, USA',
#  'Somewhere Out There',
#  'Mumbai india',
#  'sri lanka',
#  'Not a U.S resident',
#  'Lehigh Valley, PA',
#  'Canada',
#  'Thrissur',
#  'Havenford',
#  '92',
#  'Israel',
#  'Fashion Heaven. IG: TMId_',
#  'San Francisco, CA',
#  'italy',
#  'nyc',
#  'Toronto',
#  'Jackson',
#  'New York / Worldwide',
#  'New Orleans, LA',
#  'West Wales',
#  'Happily Married with 2 kids ',
#  'Cambridge, MA',
#  'Arizona ',
#  'Mumbai',
#  'Amsterdam',
#  'Swindon,England ',
#  'Williamstown, VT',
#  'North Carolina, USA',
#  'Karachi',
#  'Loveland Colorado',
#  '|| c h i c a g o ||',
#  'L. A.',
#  'VISIT MY YOUTUBE CHANNEL.',
#  'Lexington',
#  'Hannover, Germany',
#  'Playa',
#  'Davidson, NC',
#  'Higher Places',
#  'Horsemind, MI',
#  'New York, NY',
#  'Boksburg',
#  'V-RP @OZRP_ ?MV, AU, R18+?',
#  'Greater Manchester, UK',
#  'Boston',
#  'The Canopy Kingdom',
#  'the own zone layer ',
#  'London',
#  'Trancy Manor',
#  'South 37',
#  'West Lancashire, UK.',
#  'PA',
#  '\x89Û¢ Views From The Six \x89Û¢',
#  'University of Toronto',
#  'Swaning Around',
#  'Albany/NY',
#  'California, USA',
#  'Wild Wild Web',
#  'Subconscious LA',
#  'Spain',
#  'CA physically- Boston Strong?',
#  'Yeezy Taught Me , NV',
#  'Rock Hill, SC',
#  'Coolidge, AZ',
#  'Republic of Texas',
#  'Phoenix, AZ',
#  'Ljubljana, Slovenia',
#  'Connecticut',
#  'Tacoma,Washington',
#  'BIG D  HOUSTON/BOSTON/DENVER',
#  'Chandler, AZ',
#  'ColoRADo',
#  'sindria',
#  'Texas',
#  'Elk Grove, CA, USA',
#  'The Shire',
#  'Austin, TX',
#  'Oakland',
#  'Albuquerque',
#  'Buenos Aires, Argentina',
#  'San Antonio-ish, TX',
#  'Oregon, USA',
#  'Harlingen, TX',
#  'Buffalo NY',
#  'Las Vegas',
#  'Tokyo',
#  'California, United States',
#  '#FLIGHTCITY UK  ',
#  'Alphen aan den Rijn, Holland',
#  'Wrigley Field',
#  'probably the strip club',
#  'England',
#  'New York City',
#  'Here And There',
#  'Rotterdam, Zuid-Holland',
#  'Derry, 17 ',
#  'Nowhere. Everywhere.',
#  'Florida, USA',
#  'Worldwide',
#  'East Coast',
#  'California',
#  'Toronto, ON',
#  'The Orwellion police-state',
#  'Castaic, CA',
#  'Helsinki, Finland',
#  'East Kilbride',
#  'middle eastern palace',
#  'Kent',
#  'Perthshire ',
#  'twitch.tv/naturalemblem26',
#  'cyprus',
#  'Memphis, TN',
#  'Studio',
#  'Hollywood, CA',
#  'New York',
#  'Pakistan',
#  'Mexico! ^_^',
#  'Campinas Sp',
#  'Harlem, New York',
#  'Washington, DC',
#  'Burbank,CA',
#  '? ',
#  'Spokane, Washington',
#  'Charlotte, NC',
#  'Our Empire State',
#  'Jerusalem',
#  'Kingston, Pennsylvania',
#  'Milwaukee, WI',
#  'Zero Branco',
#  'bajaur',
#  'Eldoret, kenya',
#  '\x89ÛÊ\x89ÛÊ\x89ÛÊ',
#  'Miami,FL',
#  'Los Angeles, CA',
#  'North-East Region, Singapore',
#  'Chicago',
#  'EARTH ',
#  'Jerusalem, Israel',
#  'Menasha, WI',
#  'ss',
#  'Atlanta',
#  'Earth',
#  'Bleak House',
#  'heccfidmss@gmail.com',
#  'toronto',
#  '[ Blonde Bi Fry. ]',
#  'America',
#  'NYC :) Ex- #Islamophobe',
#  'SF Bay Area',
#  'Orange County, California',
#  'Winston Salem, North Carolina',
#  'Adelaide, South Australia',
#  'WASHINGTON,DC',
#  ' snapchat // fvck_casper ',
#  'Dallas, TX',
#  'NYC',
#  'Location',
#  'Selena | Britney | Hilary',
#  'Ireland',
#  'Freeport IL. USA',
#  'Dubai',
#  'Tucson, Az',
#  'Seattle WA',
#  'Bellevue NE',
#  'West Bank, Gaza Strip',
#  '\x89Û¢FLG\x89Û¢',
#  'Scotland, United Kingdom',
#  'Online 24/7. Not even kidding.',
#  'rowyso dallas ',
#  'Halton, Ontario',
#  'portland, oregon',
#  'FIMAK A.S Ist Bolge Muduru',
#  'London.',
#  '#UNITE THE BLUE  ',
#  'Dayton, Ohio',
#  'Global',
#  'ph',
#  'Port Jervis, NY',
#  'City Of Joy',
#  'Texas, USA',
#  '1/3 of the blam squad ',
#  'CCH ',
#  'atx',
#  'MAURITIUS',
#  'AKRON OHIO USA',
#  'london / st catharines ?',
#  'Peshawar',
#  'LEALMAN, FLORIDA',
#  '#GDJB #ASOT',
#  'Groningen, Netherlands, Europe',
#  'Livingston, IL  U.S.A.',
#  'Arundel ',
#  'Anna Maria, FL',
#  'israel',
#  'The Hammock, FL, USA',
#  '??????????????????',
#  'SÌ£o Paulo SP,  Brasil',
#  "in Dimitri's arms",
#  'Oslo, Norway',
#  'Los Angeles',
#  'Loughton, Essex, UK',
#  'guaravitas',
#  'Score More Goals Buying @',
#  'NEW YORK',
#  'London, Kent & SE England.',
#  'Score Team Goals Buying @',
#  'South Central Wales',
#  'Jersey City, New Jersey',
#  'Denver, CO',
#  'Brasil',
#  'Buy Give Me My Money ',
#  '505 W. Maple, Suite 100',
#  'Philippines',
#  'Freeport il ',
#  'World',
#  'Danville, VA',
#  'UK Great Britain ',
#  'Jerusalem!',
#  'San Jose, CA',
#  'Use #TMW in tweets get #RT',
#  'Utah',
#  'Wisconsin',
#  'West Richland, WA',
#  'CHICAGO (312)',
#  'Washington D.C.',
#  'NC',
#  'West Virginia, USA',
#  'British girl in Texas',
#  'Silver Spring, MD',
#  'Atlanta, GA',
#  'Manhattan, NY',
#  'Wilmington, DE',
#  'Memphis',
#  'iTunes',
#  'Oxford, MS',
#  'Pelham, AL',
#  'Jacksonville, FL',
#  'Arkansas, Jonesboro',
#  'Across the Atlantic',
#  'Melbourne, Florida',
#  'Over the Moon...',
#  'Extraterrestrial Highway',
#  'Espoo, Finland',
#  'Washington, D.C., area',
#  'OES 4th Point. sisSTAR & TI',
#  'Sydney, New South Wales',
#  'Netherlands,Amsterdam-Virtual ',
#  'Hudson Valley, NY',
#  'timeline kamu',
#  'Budapest, Hungary',
#  'Searching for Bae ',
#  'Eagle Mountain, Texas ',
#  'Columbus',
#  'Temecula, CA',
#  'Atlanta,Ga',
#  'Fresno, CA',
#  'Raleigh Durham, NC',
#  'ducked off . . . ',
#  'Rio de Janeiro',
#  '302',
#  'Columbus, OH',
#  'Mo.City',
#  'Tripsburg, ms.',
#  'Durham N.C ',
#  'Delhi',
#  'ARIZONA',
#  'Penn Hills, PA',
#  'Karachi ',
#  'seattle wa',
#  'SOUTHERN CALIFORNIA DESERT',
#  'Gotham City',
#  'My contac 27B80F7E 08170156520',
#  'Pig Symbol, Alabama',
#  'Intramuros, Manila',
#  'THE WORLD T.G.G / M.M.M ',
#  'Between the worlds ',
#  'State of Georgia',
#  'Your screen',
#  'Lima-Peru',
#  'worldwide',
#  'Saltillo, Coahuila de Zaragoza',
#  'Suitland',
#  'Everywhere',
#  'Konoha',
#  'Swag Francisco',
#  'Saint Marys, GA',
#  'Nigeria',
#  'Essex/Brighton',
#  'Pennsylvania, PA',
#  'Rockford, IL',
#  'AZ',
#  'Vero Beach , FL',
#  'IN',
#  'In the middle of no where',
#  'Baltimore, MD',
#  'dmv ?? fashion school @ KSU. ',
#  'Nice places ',
#  'Quantico, VA',
#  'Island Lake, IL',
#  'Live Oak, TX',
#  'Gages Lake, IL',
#  'Madisonville TN',
#  'Basketball City, USA ',
#  'AEP',
#  'Alberta Pack',
#  '#expelcl*y',
#  'My heart is a ghost town!',
#  'The Great State of Texas',
#  'Alicante, Valencia',
#  'Greensboro, NC',
#  ' Indiana',
#  'the local dump',
#  'Seattle',
#  '#SOUTHAMPTON ENGLAND',
#  '?205?478?',
#  'Waterford MI',
#  'Iowa, USA',
#  'va',
#  'Florida',
#  'california mermaid ? ',
#  'New York ? ATL',
#  'USA/SO FLORIDA via BROOKLYN NY',
#  'H / pez & sophia ',
#  'Brooklyn, NY',
#  'Queens, NY',
#  'Vancouver, BC.',
#  'Ottawa, Canada',
#  'wherever the $$$ at',
#  'Purgatory, USA',
#  'Calgary, Alberta',
#  'Kama | 18 | France ',
#  'Sydney',
#  'Maryland, USA',
#  'Daruka (near Tamworth) NSW',
#  'IJmuiden, The Netherlands',
#  'University Heights, Ohio',
#  'Central Illinois',
#  'Baton Rouge',
#  'PSN: Pipbois ',
#  'Colombo,Sri Lanka.',
#  'Johannesburg, South Africa ',
#  "Me mammy's belly",
#  'UK & Ibiza',
#  'Laventillemoorings ',
#  'Scotland',
#  'Vancouver, BC',
#  'Cleveland, OH',
#  'Detroit, MI, United States',
#  'Guelph Ontario Canada',
#  'Waterfront',
#  'columbus ohio',
#  'Waukesha, WI',
#  'Himalayan Mountains',
#  'Colorado/WorldWide',
#  'Ontario Canada',
#  'Houston,  TX',
#  'lakewood colorado',
#  'THE 6IX',
#  'Washington, USA',
#  'The ?? below ???',
#  'Ideally under a big tree',
#  "Conversing In Janet's CafÌ¬",
#  "???????, ??'??????",
#  "Dime's Palace",
#  'Cairo, Egypt',
#  'Seattle, WA',
#  'Bug Forest',
#  'canberra',
#  'International',
#  'The World',
#  'Htx',
#  'PunPunlÌ¢ndia',
#  '???',
#  'Itirapina, SÌ£o Paulo',
#  'North Jersey',
#  'Ewa Beach, HI',
#  'Biloxi, Mississippi',
#  'Buenos Aires',
#  'Brecksville, OH',
#  'Walthamstow, London',
#  'Malaysia',
#  'Ivano-Frankivsk',
#  'Sunshine Coast, Queensland',
#  'England,UK,Europe,Sol 3.',
#  'Nashua NH',
#  'Leicester',
#  '65',
#  'Westchester',
#  'Lynnfield, MA',
#  'Level 3 Garrison, Sector G',
#  'Singapore',
#  'Glasgow',
#  'Shity land of Northern Ireland',
#  'Christchurch New Zealand',
#  'peekskill. new york, 10566 ',
#  'PH',
#  'Storybrooke ',
#  'under the blanket',
#  'Isolated City In World Perth',
#  'Brazil ',
#  'AUS',
#  'Santa Cruz, CA',
#  'Inverness, Nova Scotia',
#  'L/S/Z/L/T/H/C/H/R/A/S/C',
#  'Oklahoma',
#  '801 SL,UT',
#  'fluffy cloud',
#  'The 5th Dimension. ',
#  'Georgia',
#  'July 11th, 2015. ?',
#  'The Grey Area',
#  'St Paul, MN',
#  'Cobblestone',
#  'ÌÏT: 30.307558,-81.403118',
#  'Cosmic Oneness',
#  'Guildford, UK',
#  'Nowhere Islands/Smash Manor',
#  'kisumu',
#  'Making Worldwide Change Near U',
#  'ATX',
#  'LA/OC/Vegas',
#  'London/Outlaw Country ',
#  'Grimsby, England',
#  'Gotham',
#  'Manchester, The World, England',
#  'sitting on Eddie Vedders lap,',
#  'Missouri, USA',
#  'Greenville,SC',
#  'Paignton',
#  'have car; will travel',
#  'ATL ? SEA ',
#  'ÌÏT: 39.982988,-75.261624',
#  '#EngleWood CHICAGO ',
#  '302???? 815',
#  'New Your',
#  'PURPLE BOOTH STUDIO\x89ã¢',
#  'Cloud 9',
#  'Former Yugoslav Republic of Macedonia',
#  '3?3?7?SLOPelousas??2?2?5?',
#  '316',
#  "#WhereverI'mAt",
#  'Huber Heights, OH',
#  'Miami ??',
#  'Houston, TX',
#  'Every where',
#  "401 livin'",
#  'MI',
#  'EPTX',
#  'Austin, Texas',
#  'Oklahoma City',
#  'CA',
#  'United Kingdom',
#  'WESTSIDE OF PHILLY 7? BLOCK??',
#  'Charlotte NC',
#  'LONG ISLAND, NY',
#  'washington, d.c.',
#  'WAISTDEEP, TX',
#  'D.C. - Baltimore - Annapolis',
#  '#937??#734',
#  'Fife, WA',
#  'Bushkill pa',
#  'In the Shadows...',
#  'southwest, Tx',
#  'ANYWEHERE !!',
#  'Menlo Park. SFO. The World.',
#  'Speaking the Truth in Love',
#  'Aarhus, Central Jutland',
#  'Lincoln, NE',
#  'wny',
#  'Bolton & Tewkesbury, UK',
#  "travelling to tae's pants",
#  'keli x',
#  'Manchester',
#  'Knoxville, TN',
#  'ChicagoRObotz',
#  "whs '17",
#  'NV',
#  'lagos nigeria',
#  'Edmonton, Alberta',
#  '[Gia.] | #KardashianEmpire',
#  'Sunrise Manor, NV',
#  'Oxford, OH',
#  'Odawara, Japan',
#  'Chicago, IL',
#  'Des Moines, IA',
#  'Dundas, Ontario',
#  'IDN',
#  'Netherlands',
#  'DaKounty, Pa',
#  'DÌ_sseldorf, Germany',
#  'Old Blighty',
#  '??',
#  'The land of New Jersey. ',
#  'Atlanta Georgia',
#  'MY RTs ARE NOT ENDORSEMENTS',
#  'Kabul, Tuebingen, Innsbruck',
#  'Light and dark, form and void',
#  'Nairobi, Kenya ',
#  'Erbil',
#  'Stockton on tees Teesside UK',
#  'Screwston, TX',
#  'My old New England home',
#  'melbourne',
#  'Cape Town',
#  'Ikeja, Nigeria',
#  'Warwick, RI @Dollarocracy also',
#  'texas a&m university',
#  'MA',
#  'Shipwreck Cove',
#  'Sydney, Australia',
#  'WorldWide',
#  'Overland Park, KS',
#  'SWMO',
#  'Puerto Rico',
#  'Toronto-Citizen of Canada & US',
#  'Silicon Valley',
#  'North East USA',
#  'Washington, D.C.',
#  'VitÌ_ria (ES)',
#  'New Delhi, Delhi',
#  'Buscame EL tu Melte',
#  'Wiltshire',
#  'PROUD INDIANS',
#  'Mumbai , India',
#  'Pittsburgh PA',
#  'MUM-DEL',
#  'Leeds, England',
#  'Playa del Carmen, Mexico',
#  'NY, CT & Greece',
#  'Mackay, QLD, Australia',
#  'Quincy MA',
#  'NJ',
#  'Madison, GA',
#  'KurveZ@GearHeadCentral.net',
#  'St Charles, MD',
#  'Denver, Colorado',
#  'Ziam af ',
#  'GO BLUE! HAIL YES!!',
#  'Outside The Matrix, I Think.',
#  'In Hell',
#  'Epic City, BB.',
#  'somewhere over a rainbow',
#  'Selma2Oakland',
#  'Bombardment Bay',
#  'Savannah, GA',
#  'dallas',
#  'New Orleans ,Louisiana',
#  'England, United Kingdom',
#  'Dublin City, Ireland',
#  'New Hampshire',
#  'World Wide',
#  'Intermountain West',
#  'Tulsa, Oklahoma',
#  'Auburn, AL',
#  'taken by piper curda',
#  'Scotland ',
#  'Nigeria, Global',
#  'Fort Walton Beach, Fl',
#  'Sweden',
#  'Groton, CT',
#  'Brisbane Australia',
#  'NY Capital District',
#  'Peoria',
#  'Reading UK',
#  'Concord, NH ',
#  'CORNFIELDS',
#  'Worcester, MA',
#  'Roanoke, VA',
#  'nj',
#  'MA via PA',
#  'Boston, MA',
#  'Oklahoma City, OK',
#  'toronto \x89Û¢ dallas',
#  'San Diego CA',
#  'germany',
#  'Massachusetts',
#  ' Nxgerxa',
#  'Erie, PA',
#  'Port Charlotte, FL',
#  'Belleville, Illinois',
#  'Alabama',
#  'Long Island NY & San Francisco',
#  'Gainesville, FL',
#  'Oakland, CA',
#  '956',
#  'Escondido, CA',
#  'DC',
#  'Chicago Area',
#  'Upper St Clair, PA',
#  'Cherry Creek Denver CO',
#  '627',
#  'Blogland',
#  'mumbai',
#  'Isle of Man',
#  'Hampton Roads, VA',
#  'Gameday',
#  'Earthling (For now!)',
#  'Black Canyon New River, AZ',
#  'Caracas, Venezuela.',
#  'NY',
#  'Charlottetown',
#  'Paradise, NV',
#  '??t?a',
#  'LiÌ¬ge',
#  'Spokane, Washington 99206',
#  'taco bell',
#  'Australian Capital Territory',
#  'http://www.amazon.com/dp/B00HR',
#  '[ kate + they/them + infp-t ]',
#  'Sacramento, CA',
#  'please H? ?:??',
#  'we?it \x89Û¢ ixwin',
#  'Santiago Bernabeau',
#  'y/e/l',
#  'Whiterun, Skyrim',
#  'Greenpoint, Brooklyn',
#  'Victoria, British Columbia',
#  'a botanical garden probably',
#  'Nelspruit, South Africa',
#  'midwest',
#  'Copenhagen, Capital Region of Denmark',
#  'Spying on your thoughts',
#  'seattle grace mercy death',
#  'Tucson, Arizona ',
#  'Charlotte County Florida',
#  'Head Office: United Kingdom',
#  'Mid north coast of NSW',
#  'iPhone: -27.499212,153.011072',
#  'Queen Creek AZ',
#  'Jamaica',
#  'Trinidad and Tobago',
#  'Melbourne Australia',
#  'The Internet & NYC',
#  'London/Bristol/Guildford',
#  'Canberra, Australian Capital Territory',
#  'beacon hills ',
#  'somewhere outside',
#  'Wolmers Trust School for Boys ',
#  'Loughborough.',
#  'Selangor',
#  'indiana',
#  'Bronx, New York',
#  'Canadian bread',
#  "Le Moyne '16",
#  'Hoxton, London',
#  'Las Vegas, NV USA',
#  'Heinz Field ',
#  'Skyport de la Rosa',
#  'The Low-Cal Calzone Zone',
#  'Brooklyn, New York',
#  '50% Queanbeyan - 50% Sydney',
#  'Insula Barataria',
#  'everywhere ',
#  'Afghanistan, USA',
#  'Inglewood, CA',
#  'Absecon, NJ',
#  'Williamsbridge, Bronx, New Yor',
#  'Northern Kentucky, USA',
#  'Mostly Yuin.',
#  'Nairobi',
#  'Rochelle, GA',
#  'London UK',
#  'south of heaven ',
#  'El Dorado, KS',
#  'Santa Monica, CA',
#  'Kenya',
#  '1648 Queen St. West, Toronto.',
#  'Toledo, OH',
#  'Fairfield, California',
#  'Trinity, Bailiwick of Jersey',
#  'Virginia',
#  'LIVERPOOL',
#  'Boulder, CO',
#  'Hospital, bc of SKH vid.',
#  'Hartford  London Hong Kong',
#  "In @4SkinChan 's arms",
#  'Massachusetts, USA',
#  'Kansas City, MO',
#  'Wellington, New Zealand',
#  '?? ??',
#  'los angeles, ca',
#  'New Brunswick, NJ',
#  'City of Angels, CA',
#  'Morganville, Texas.',
#  'America | New Zealand ',
#  'Stockholm, Sweden',
#  'Azeroth',
#  "Lytham St Anne's ",
#  'Ylisse',
#  'Portugal',
#  'All around the world baby',
#  '@UntmdOutdoors #T.O.R.K ',
#  'Lima, PerÌ¼',
#  'Piedmont Area, North Carolina',
#  'Buxton, Venice, and Nottingham',
#  'Quito, Ecuador.',
#  'Inexpressible Island ',
#  ' Bouvet Island',
#  'Shirley, NY',
#  'Planet Earth',
#  'Paonia, Colorado ',
#  'Portland, OR',
#  'Dublin, Ireland',
#  'Lurking',
#  'N?? Y???.',
#  'Littleton, CO, USA',
#  'Virginia, United States',
#  'Center for Domestic Preparedness',
#  'Ukraine and Ireland',
#  'Welt',
#  'Wales',
#  'Seattle, Washington',
#  'Beaumont, TX',
#  'Annapolis, MD',
#  'Las Vegas, Nevada',
#  'Harris County, Texas',
#  'Tyler, TX',
#  'Evanston, IL',
#  'North Ferriby, East Yorkshire',
#  'Colombia',
#  'Ames, Iowa',
#  'Moscow, Russia',
#  'Jersey City, NJ',
#  'Mankato, MN',
#  'Orbost, Victoria, Australia',
#  ' Somewhere.',
#  ' Neverland ',
#  'London, England',
#  'At Da Laundry Mat Wit Nivea ',
#  'norway',
#  '$ad $hawty',
#  'NY || live easy? ',
#  'BestCoast',
#  'BC',
#  'Abuja, Nigeria',
#  'Colchester Essex ',
#  'livin life in the 610',
#  'Suplex City',
#  'Inside your mind.',
#  '36 & 38',
#  'Sydney Australia',
#  'Lagos, Nigeria',
#  'New York, NY ',
#  'Slappin and Smackin ',
#  "DRAW A CIRCLE THAT'S THE EARTH",
#  'Madrid, Comunidad de Madrid',
#  'The Netherlands',
#  'Highland Park, CA',
#  'Swan River',
#  'Kolkata, India',
#  'Melrose',
#  'Jubail IC, Saudi Arabia',
#  'Sugarhouse, UT',
#  'lugo',
#  'Chicago, Illinois',
#  'Blackpool, England, UK.',
#  'San Jose, California',
#  'Fakefams',
#  'In the clouds...',
#  'Sandton, South Africa',
#  'Nigeria ',
#  '#Bummerville otw',
#  'Europe',
#  'Brighton and Hove',
#  'Pompano Beach, FL',
#  'JKT48-Muse-A7X',
#  'Behind The Obama Curtain',
#  'Worldwide.',
#  'LiVE MÌ\x81S',
#  'Henderson, NV',
#  'CAMARILLO, CA',
#  'manchester, uk.',
#  'Eugene, Oregon',
#  'they/her',
#  'Paris ',
#  '(he/him)',
#  'Kingston, Jamaica',
#  'Spokane, WA',
#  "I'm standing behind you",
#  'Alexandria, Egypt.',
#  'instagram- Chloe_Bellx',
#  'on the web',
#  'San Francisco Bay Area',
#  '#ForeverWithBAP 8 ',
#  'GOT7SupportPH',
#  'wherever-the-fuck washington',
#  'From NY. In Scranton, PA',
#  'Perth, Western Australia',
#  'Live mÌÁs',
#  'Melton, GA',
#  "Greg's place",
#  'Viejo',
#  'Kansas, The Free State! ~ KC',
#  'Silang, Cavite / ParaÌ±aque',
#  'Fort Smith, AR',
#  'planeta H2o',
#  'www.youtube.com?Malkavius2',
#  'Michigan',
#  'The Forever Girl',
#  'EspÌ_rito Santo',
#  'New York, USA',
#  'Ormond By The Sea, FL',
#  'Maryland,Baltimore',
#  'Pennsylvania, USA',
#  'Houston, Texas',
#  'Yadkinville, NC',
#  'Medford, NJ',
#  'Dallas, Texas. ',
#  'Roanoke VA',
#  'Unnamed City',
#  'Peterborough, On',
#  '-6.152261,106.775995',
#  "@protectingtitan's side.",
#  'Oregon',
#  'Eau Claire, Wisconsin',
#  'St. Joseph, Minnesota',
#  'From a torn up town MANCHESTER',
#  'Waco TX',
#  'Tennessee',
#  'Cape Cod, Massachusetts USA',
#  'bk. ',
#  'Lansing, Michigan',
#  'Peterborough, Ont.',
#  'Johannesburg, South Africa',
#  'On the court ',
#  'Traverse City, MI',
#  'See the barn of bleakness',
#  'Hertfordshire ',
#  'ÌÏT: 41.252426,-96.072013',
#  'California ',
#  'Greeley, CO',
#  "'soooota",
#  'Sacramento',
#  'Ontario, Canada',
#  'NY, NY',
#  'Arvada, CO',
#  'Maryland',
#  'Vancouver, Colombie-Britannique',
#  'Irving , Texas',
#  'Riverside, CA',
#  'SEATTLE, WA USA',
#  'USA , AZ',
#  'East Atlanta, Georgia',
#  'Saint Lucia',
#  'Peterborough, Ontario, Canada',
#  'Colorado',
#  'North Highlands, CA',
#  'Vancouver',
#  '60th St (SS)',
#  'USA, WA',
#  'btwn a rock and a hard place',
#  'Aix-en-Provence, France',
#  'Liverpool',
#  'I-75 in Florida',
#  '21.462446,-158.022017',
#  'Melbourne, Australia',
#  'Darlington',
#  '  Melbourne, Australia',
#  'Kenton, Ohio',
#  'Galatians 2:20 ',
#  'Charleston, SC',
#  'Lancaster, Pennsylvania, USA',
#  'In my own world!!!',
#  'Definitely NOT the stables',
#  'Cuernavaca, Morelos, MÌ©xico.',
#  'Va Beach, Virginia',
#  '52.479722, 62.184971',
#  'The Pig Sty',
#  'Bangor, Co.Down',
#  'Weston super mare',
#  'Victoria, Tx.',
#  'Pakistan, Islamabad',
#  'Gujranwala, Pakistan',
#  'Lindenhurst',
#  'Islamabad',
#  'Somewhere',
#  'too far',
#  'Kingswinford',
#  'i love the smurfs 2',
#  'International ',
#  "Viterbo BFA Acting '18",
#  'Kaneohe',
#  'Houma La',
#  "EastAtlanta ??#WestGeorgia'18",
#  'San Antonio, TX',
#  'Cleveland, Ohio',
#  'San Diego, Texas.',
#  'GLOBAL',
#  '05/04/2014 18:23 ?',
#  'Bolivar, MO',
#  'taking pain like pleasure',
#  'San Fransokyo',
#  'Washington, DC NATIVE',
#  'Miami, FL',
#  'w. Nykae ',
#  'honeymoon avenue',
#  'Toronto, Worldwide ',
#  '11/4/14',
#  "wherever there's netflix",
#  '#HAMont',
#  'U.K.',
#  'online ',
#  'Conroe, TX',
#  'Ontario, Canada. ',
#  'Guayaquil',
#  'bahstun/porta reeko',
#  'Bucks County, Pa',
#  'Sunny South florida ',
#  'Rio',
#  'Neverland',
#  'Trinidad & Tobago',
#  'Chicago - Lake Buena Vista',
#  'Toronto, Ontario',
#  'Liberty Lake, WA',
#  'Ankara - Malatya - ad Orontem',
#  'antioch, california',
#  'State College, PA',
#  'somewhere in cali ',
#  'Im Around ... Jersey',
#  'Garden Grove',
#  'Adelaide, Australia',
#  'BKI-KUA',
#  'urÌ£nus',
#  'Illinois, USA',
#  ...]

# %%
pd.crosstab(train['location'], train['target'])
# Out:
# target                  0  1
# location
#                         0  1
#   Glasgow               1  0
#   Melbourne, Australia  1  0
#   News                  0  1
#   å_                    1  0
# ...                    .. ..
# å_: ?? ÌÑ ? : ?         1  0
# å_å_Los Mina Cityã¢    1  0
# å¡å¡Midwest Û¢Û¢      1  0
# åÊ(?Û¢`?Û¢å«)??       1  0
# åø\_(?)_/åø             0  1
#
# [3341 rows x 2 columns]

# %%
test['location'].value_counts()
# Out:
# New York                  38
# USA                       37
# Worldwide                 16
# United States             15
# London                    13
#                           ..
# Medford, NJ                1
# Quezon City                1
# LanÌ¼s                     1
# USA,Washington,Seattle     1
# Brussels, Belgium          1
# Name: location, Length: 1602, dtype: int64

# %%
np.isin(test['location'].unique(), train['location'].unique())
# Out:
# array([False,  True, False, ..., False,  True, False])

# %% [markdown]
# # Basic Feature Engineering

# %%
train = train[['keyword', 'text', 'target']]
test = test[['id', 'keyword', 'text']]

train['char_count'] = train['text'].apply(lambda x: count_chars(x))
train['word_count'] = train['text'].apply(lambda x: count_words(x))
train['sent_count'] = train['text'].apply(lambda x: count_sent(x))
train['capital_char_count'] = train['text'].apply(lambda x: count_capital_chars(x))
train['capital_word_count'] = train['text'].apply(lambda x: count_capital_words(x))
# train['quoted_word_count'] = train['text'].apply(lambda x: count_words_in_quotes(x))
train['stopword_count'] = train['text'].apply(lambda x: count_stopwords(x))
train['unique_word_count'] = train['text'].apply(lambda x: count_unique_words(x))
                                                 
test['char_count'] = test['text'].apply(lambda x: count_chars(x))
test['word_count'] = test['text'].apply(lambda x: count_words(x))
test['sent_count'] = test['text'].apply(lambda x: count_sent(x))
test['capital_char_count'] = test['text'].apply(lambda x: count_capital_chars(x))
test['capital_word_count'] = test['text'].apply(lambda x: count_capital_words(x))
# test['quoted_word_count'] = test['text'].apply(lambda x: count_words_in_quotes(x))
test['stopword_count'] = test['text'].apply(lambda x: count_stopwords(x))
test['unique_word_count'] = test['text'].apply(lambda x: count_unique_words(x))
                                                 
## Average word length
train['avg_wordlength'] = train['char_count'] / train['word_count']
test['avg_wordlength'] = test['char_count'] / test['word_count']

## Average sentence lenght
train['avg_sentlength'] = train['word_count'] / train['sent_count']
test['avg_sentlength'] = test['word_count'] / test['sent_count']

## Unique words vs count words
train['unique_vs_words'] = train['unique_word_count'] / train['word_count']
test['unique_vs_words'] = test['unique_word_count'] / test['word_count']

## stopwords vs count words
train['stopwords_vs_words'] = train['stopword_count'] / train['word_count']
test['stopwords_vs_words'] = test['stopword_count'] / test['word_count']

# %% [markdown]
# # Baseline Model: Logistic Regression

# %%
## Defining input and target variables 
X = train.drop(columns = ['keyword', 'text', 'target'], axis = 1)
Y = train['target']

## Defining the hyper-parameter grid
logistic_param_grid = {'penalty': ['l1', 'l2', 'elasticnet'],
                       'C': [0.001, 0.01, 0.1, 1, 10, 100],
                       'solver': ['liblinear', 'sag', 'saga']}

## Performing grid search with 5 folds
logistic_grid_search = GridSearchCV(LogisticRegression(), logistic_param_grid, cv = 5, scoring = 'f1', n_jobs = -1, verbose = 3).fit(X, Y)

## Printing the best hyper-parameter combination
print(logistic_grid_search.best_params_)

## Printing the best score
print(logistic_grid_search.best_score_)

## Extraciting the best model 
logit_md = logistic_grid_search.best_estimator_
print(logit_md)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 120 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 457, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.34308617        nan 0.37663757 0.52132828 0.52246603 0.52192586
#         nan        nan        nan 0.52369763        nan 0.52312
#  0.52819977 0.5283405  0.52929696        nan        nan        nan
#  0.52872109        nan 0.52875625 0.52933884 0.52915879 0.52876641
#         nan        nan        nan 0.528994          nan 0.52916494
#  0.53008215 0.52905887 0.52933584        nan        nan        nan
#  0.53019375        nan 0.5290767  0.53004592 0.52905887 0.52953205
#         nan        nan        nan 0.53072219        nan 0.52943057
#  0.52958694 0.52905887 0.52933584        nan        nan        nan]
#   warnings.warn(
# {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.5307221931561943
# LogisticRegression(C=100, penalty='l1', solver='liblinear')

# %%
def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]


logit_pred = logit_md.predict_proba(X)[:, 1]
opt_cutoff = precision_recall_cutoff(Y, logit_pred)
print('The optimal cutoff is', opt_cutoff)

## Predicting on test 
logit_test_pred = logit_md.predict_proba(test.drop(columns = ['id', 'keyword', 'text'], axis = 1))[:, 1]

## Changing likelihoods to labels
logit_test_label = np.where(logit_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test['id'], 'target': logit_test_label})
data_out.to_csv('Logistic_submission_1.csv', index = False)

data_out['target'].value_counts() / data_out.shape[0]
# Out:
# The optimal cutoff is 0.3354156955232394
# 1    0.675759
# 0    0.324241
# Name: target, dtype: float64

# %% [markdown]
# # Baseline Model: Random Forest

# %%
## Defining input and target variables 
X = train.drop(columns = ['keyword', 'text', 'target'], axis = 1)
Y = train['target']

RF_param_grid = {'n_estimators': [100, 300, 500],
                 'max_features': [3, 4, 5],
                 'max_depth': [3, 5, 7],
                 'min_samples_split': [5, 7, 9],
                 'min_samples_leaf': [5, 7, 9]}
        
## Running leave-one-out cross validation 
RF_grid_search = GridSearchCV(RandomForestClassifier(), RF_param_grid, cv = 5, scoring = 'f1', n_jobs = -1, verbose = 3).fit(X, Y)

## Printing the best hyper-parameter combination
print(RF_grid_search.best_params_)

## Extraciting the best model 
RF_md = RF_grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.551 total time=   1.9s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.497 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.597 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.549 total time=   1.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.591 total time=   3.1s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.501 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.575 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.498 total time=   1.4s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.594 total time=   2.8s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.562 total time=   2.4s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.499 total time=   2.9s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.601 total time=   1.6s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.595 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.550 total time=   1.5s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.563 total time=   2.9s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.548 total time=   2.9s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.506 total time=   3.3s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.590 total time=   2.3s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.556 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.611 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.576 total time=   1.7s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.508 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.571 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.615 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.569 total time=   1.7s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.500 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.567 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.613 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.579 total time=   1.7s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.509 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.561 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.500 total time=   1.7s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.596 total time=   3.0s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.559 total time=   2.8s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.601 total time=   1.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.554 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.601 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.579 total time=   1.9s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.500 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.586 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.501 total time=   1.7s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.594 total time=   3.0s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.506 total time=   3.0s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.607 total time=   2.1s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.596 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.555 total time=   2.0s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.615 total time=   3.1s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.581 total time=   3.1s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.609 total time=   2.0s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.565 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.608 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.571 total time=   1.9s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.614 total time=   3.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.556 total time=   3.4s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.610 total time=   1.9s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.588 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.592 total time=   2.1s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.515 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.588 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.520 total time=   2.2s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.612 total time=   3.4s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.561 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.504 total time=   2.9s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.501 total time=   2.5s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.554 total time=   1.5s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.566 total time=   2.4s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.569 total time=   2.8s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.548 total time=   2.4s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.605 total time=   1.6s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.553 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.500 total time=   1.7s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.606 total time=   2.9s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.592 total time=   2.7s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.500 total time=   2.8s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.593 total time=   1.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.552 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.610 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.567 total time=   2.1s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.502 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.606 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.561 total time=   1.6s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.596 total time=   2.8s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.608 total time=   1.6s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.586 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.558 total time=   1.8s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.610 total time=   2.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.566 total time=   2.9s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.597 total time=   1.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.551 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.611 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.564 total time=   1.7s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.610 total time=   3.0s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.579 total time=   3.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.505 total time=   2.8s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.605 total time=   1.9s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.562 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.607 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.576 total time=   1.9s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.505 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.561 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.612 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.570 total time=   1.8s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.512 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.553 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.611 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.580 total time=   1.9s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.612 total time=   3.4s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.599 total time=   3.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.503 total time=   3.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.613 total time=   1.9s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.588 total time=   0.7s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.505 total time=   1.8s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.600 total time=   3.1s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.556 total time=   3.3s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.586 total time=   2.0s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.551 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.611 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.592 total time=   1.9s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.517 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.548 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.618 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.591 total time=   1.7s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.605 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.606 total time=   1.6s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.545 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.603 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.566 total time=   1.6s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.494 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.604 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.598 total time=   1.5s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.549 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.599 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.569 total time=   1.6s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.495 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.561 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.604 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.569 total time=   1.5s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.606 total time=   2.4s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.564 total time=   2.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.497 total time=   2.4s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.595 total time=   1.6s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.508 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.587 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.556 total time=   2.1s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.507 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.593 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.559 total time=   1.7s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.612 total time=   3.6s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.594 total time=   3.1s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.558 total time=   3.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.506 total time=   2.9s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.592 total time=   1.6s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.570 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.606 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.564 total time=   1.8s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.609 total time=   2.7s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.570 total time=   3.0s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.611 total time=   1.7s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.589 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.503 total time=   1.9s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.593 total time=   3.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.558 total time=   3.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.608 total time=   1.8s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.581 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.501 total time=   2.1s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.592 total time=   3.1s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.551 total time=   3.4s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.561 total time=   3.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.604 total time=   2.1s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.591 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.503 total time=   1.9s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.571 total time=   3.3s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.504 total time=   3.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.598 total time=   1.7s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.548 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.613 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.516 total time=   2.0s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.585 total time=   3.2s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.551 total time=   3.3s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.611 total time=   1.9s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.592 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.553 total time=   1.8s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.615 total time=   3.2s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.503 total time=   1.7s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.592 total time=   2.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.568 total time=   3.2s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.553 total time=   2.3s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.607 total time=   1.6s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.590 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.551 total time=   1.6s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.503 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.571 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.503 total time=   1.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.591 total time=   2.8s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.564 total time=   2.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.504 total time=   2.7s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.600 total time=   1.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.556 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.609 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.505 total time=   1.8s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.596 total time=   3.2s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.577 total time=   3.3s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.504 total time=   2.9s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.603 total time=   1.7s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.548 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.509 total time=   1.8s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.597 total time=   3.0s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.582 total time=   2.9s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.607 total time=   1.7s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.575 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.503 total time=   1.6s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.575 total time=   3.1s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.610 total time=   1.9s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.602 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.553 total time=   1.8s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.607 total time=   3.4s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.609 total time=   3.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.572 total time=   3.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.503 total time=   3.3s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.606 total time=   1.9s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.555 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.604 total time=   0.7s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.567 total time=   2.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.501 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.606 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.556 total time=   2.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.508 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.579 total time=   0.7s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.504 total time=   1.9s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.578 total time=   3.2s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.503 total time=   3.2s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.596 total time=   2.0s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.549 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.620 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.589 total time=   2.0s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.514 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.582 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.551 total time=   1.9s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.610 total time=   3.1s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.589 total time=   3.0s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.584 total time=   2.0s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.591 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.613 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.587 total time=   2.0s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.503 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.603 total time=   1.7s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.558 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.499 total time=   1.4s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.545 total time=   2.7s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.606 total time=   1.4s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.609 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.558 total time=   1.4s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.605 total time=   2.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.502 total time=   2.4s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.595 total time=   1.7s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.567 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.604 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.558 total time=   1.4s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.493 total time=   0.4s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.574 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.503 total time=   1.9s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.607 total time=   3.0s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.593 total time=   3.0s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.577 total time=   3.1s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.613 total time=   2.1s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.575 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.503 total time=   1.8s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.608 total time=   3.2s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.571 total time=   3.1s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.564 total time=   3.0s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.605 total time=   2.0s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.602 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.563 total time=   1.6s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.591 total time=   3.0s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.559 total time=   3.2s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.509 total time=   3.1s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.597 total time=   1.7s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.565 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.605 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.582 total time=   1.9s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.510 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.591 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.559 total time=   2.0s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.608 total time=   3.2s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.578 total time=   3.1s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.504 total time=   3.4s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.503 total time=   3.3s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.599 total time=   2.3s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.556 total time=   0.7s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.618 total time=   0.7s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.585 total time=   2.0s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.503 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.599 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.563 total time=   2.1s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.611 total time=   3.5s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.588 total time=   3.3s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.517 total time=   3.2s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.595 total time=   2.0s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.592 total time=   0.7s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.520 total time=   1.7s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.593 total time=   3.0s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.555 total time=   3.2s
# [CV 4/5] END max_depth=5, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.585 total time=   2.2s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.561 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.613 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.603 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.567 total time=   2.8s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.609 total time=   1.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.568 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.499 total time=   1.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.496 total time=   2.4s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.596 total time=   1.7s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.578 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.505 total time=   1.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.597 total time=   2.4s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.552 total time=   2.5s
# [CV 4/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.594 total time=   1.4s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.554 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.603 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.566 total time=   1.8s
# [CV 2/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.540 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.607 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.572 total time=   1.8s
# [CV 5/5] END max_depth=3, max_features=3, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.602 total time=   2.5s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.557 total time=   3.5s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.502 total time=   3.6s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.610 total time=   1.9s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.607 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.563 total time=   1.8s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.609 total time=   3.1s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.577 total time=   2.7s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.609 total time=   1.8s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.578 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.608 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.567 total time=   1.7s
# [CV 1/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.504 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.587 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.560 total time=   1.7s
# [CV 4/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.596 total time=   3.1s
# [CV 2/5] END max_depth=3, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.557 total time=   2.9s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.612 total time=   1.7s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.571 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.505 total time=   1.9s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.578 total time=   3.0s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.506 total time=   3.2s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.600 total time=   2.0s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.570 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.505 total time=   1.9s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.593 total time=   3.5s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.559 total time=   3.4s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.616 total time=   2.0s
# [CV 4/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.605 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.560 total time=   1.9s
# [CV 5/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.608 total time=   3.3s
# [CV 3/5] END max_depth=3, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.575 total time=   3.2s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.521 total time=   3.4s
# [CV 5/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.620 total time=   2.1s
# [CV 3/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.589 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.523 total time=   1.8s
# [CV 2/5] END max_depth=5, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.553 total time=   3.3s
# ...
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.589 total time=   2.7s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.589 total time=   0.9s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.526 total time=   3.0s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.569 total time=   4.6s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.544 total time=   4.5s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.621 total time=   2.7s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.589 total time=   1.0s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.529 total time=   2.6s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.591 total time=   4.4s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.620 total time=   2.7s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.586 total time=   0.9s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.527 total time=   2.6s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.574 total time=   4.8s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.547 total time=   5.4s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.614 total time=   3.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.578 total time=   1.0s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.529 total time=   3.2s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.617 total time=   4.7s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.553 total time=   4.6s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.586 total time=   3.0s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.553 total time=   1.1s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.624 total time=   1.2s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.588 total time=   3.6s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.542 total time=   1.0s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.582 total time=   1.0s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.534 total time=   3.1s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.588 total time=   5.4s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.548 total time=   4.9s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.534 total time=   4.6s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.583 total time=   2.7s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.522 total time=   1.0s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.594 total time=   1.5s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.582 total time=   3.0s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.524 total time=   1.0s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.573 total time=   0.9s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.546 total time=   3.1s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.616 total time=   4.6s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.574 total time=   4.7s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.548 total time=   4.5s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.620 total time=   3.0s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.574 total time=   1.1s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.541 total time=   3.2s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.614 total time=   5.3s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.585 total time=   5.2s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.622 total time=   2.9s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.564 total time=   1.0s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.547 total time=   3.0s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.616 total time=   5.0s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.592 total time=   5.4s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.532 total time=   5.5s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.579 total time=   3.0s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.548 total time=   1.1s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.612 total time=   1.3s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.588 total time=   3.1s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.533 total time=   1.1s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.589 total time=   1.0s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.552 total time=   3.0s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.611 total time=   4.1s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.584 total time=   2.9s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.531 total time=   1.0s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=100;, score=0.587 total time=   1.0s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.530 total time=   3.1s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.622 total time=   4.7s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.586 total time=   4.9s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.615 total time=   2.7s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=100;, score=0.585 total time=   1.0s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.528 total time=   3.0s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.571 total time=   4.5s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.542 total time=   4.8s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.526 total time=   4.4s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.570 total time=   2.8s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.540 total time=   1.0s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.614 total time=   1.1s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=0.585 total time=   3.4s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.539 total time=   1.1s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=0.575 total time=   1.1s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.548 total time=   3.2s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.613 total time=   5.4s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.589 total time=   4.8s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=500;, score=0.533 total time=   5.1s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.533 total time=   5.4s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=300;, score=0.570 total time=   3.0s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.542 total time=   1.2s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=100;, score=0.576 total time=   1.0s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=300;, score=0.589 total time=   3.5s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.540 total time=   1.1s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=100;, score=0.586 total time=   1.0s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.534 total time=   3.3s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=500;, score=0.572 total time=   5.1s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.584 total time=   5.1s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=300;, score=0.542 total time=   2.8s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.571 total time=   4.4s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=5, min_samples_split=9, n_estimators=500;, score=0.525 total time=   4.6s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.571 total time=   2.8s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.547 total time=   0.9s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.622 total time=   1.1s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.548 total time=   2.7s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.623 total time=   4.6s
# [CV 3/5] END max_depth=7, max_features=4, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.593 total time=   4.6s
# [CV 1/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.528 total time=   4.7s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.574 total time=   2.8s
# [CV 4/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.591 total time=   1.0s
# [CV 2/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.543 total time=   2.8s
# [CV 5/5] END max_depth=7, max_features=4, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.614 total time=   4.8s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=0.593 total time=   5.4s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=7, n_estimators=500;, score=0.530 total time=   5.4s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=9, n_estimators=300;, score=0.573 total time=   3.2s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.553 total time=   1.1s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=100;, score=0.611 total time=   1.1s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=5, n_estimators=300;, score=0.587 total time=   2.7s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.527 total time=   1.1s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=100;, score=0.588 total time=   1.2s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=300;, score=0.527 total time=   3.5s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=7, n_estimators=500;, score=0.610 total time=   5.1s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=7, min_samples_split=9, n_estimators=500;, score=0.573 total time=   5.4s
# [CV 2/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=5, n_estimators=500;, score=0.543 total time=   5.4s
# [CV 5/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=7, n_estimators=300;, score=0.616 total time=   3.2s
# [CV 3/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=100;, score=0.592 total time=   0.9s
# [CV 1/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=300;, score=0.530 total time=   3.1s
# [CV 4/5] END max_depth=7, max_features=5, min_samples_leaf=9, min_samples_split=9, n_estimators=500;, score=0.586 total time=   4.8s

# %%
## Printing the best hyper-parameter combination
print(RF_grid_search.best_params_)

## Printing best F1-score
print(RF_grid_search.best_score_)
# Out:
# {'max_depth': 7, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 100}
# 0.5777967006001864

# %%
## Extraciting the best model 
RF_md = RF_grid_search.best_estimator_

## Predicting on train to estimate cutoff based on precision-recall curve
RF_pred = RF_md.predict_proba(X)[:, 1]
RF_pred
# Out:
# array([0.31321896, 0.18545234, 0.41631674, ..., 0.49013988, 0.46691624,
#        0.64951801])

# %% [markdown]
# # Playing with seed

# %%
results_train = []
results_test = []

for i in range(0, 100):
    
    ## Building the model 
    RF = RandomForestClassifier(n_estimators = 100, max_depth = 7, max_features = 5, min_samples_leaf = 7, min_samples_split = 9, random_state = i).fit(X, Y)
    
    ## Predicting 
    results_train.append(pd.Series(RF.predict_proba(X)[:, 1]))
    results_test.append(pd.Series(RF.predict_proba(test.drop(columns = ['id', 'keyword', 'text'], axis = 1))[:, 1]))

# %%
results_train = pd.concat(results_train, axis = 1)
RF_pred = results_train.apply('mean', axis = 1)

results_test = pd.concat(results_test, axis = 1)
RF_test_pred = results_test.apply('mean', axis = 1)

# %%
# RF_md = RandomForestClassifier(n_estimators = 100, max_depth = 7, max_features = 5, min_samples_leaf = 7, min_samples_split = 9, random_state = 100).fit(X, Y)

# RF_pred = RF_md.predict_proba(X)[:, 1]

# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import precision_recall_curve

'''
The precision_recall_cutoff function takes 2 arguments:
Y_test: actual labels from the test data-frame
Y_pred: predicted likelihoods from a model 
This function estimated the optimal cutoff value based 
on the precision_recall_curve function and returns the 
predicted labels based onn the optimal cutoff value from 
the precision_recall_curve function.
'''

def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

# %%
opt_cutoff = precision_recall_cutoff(Y, RF_pred)
opt_cutoff
# Out:
# 0.3527323101436399

# %%
## Predicting on test 
# RF_test_pred = RF_md.predict_proba(test.drop(columns = ['id', 'keyword', 'text'], axis = 1))[:, 1]

## Changing likelihoods to labels
RF_test_label = np.where(RF_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test['id'], 'target': RF_test_label})
data_out.to_csv('RF_submission_4.csv', index = False)

# data_out['target'].value_counts() / data_out.shape[0] (best proportion)
# 1    0.54643
# 0    0.45357

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.54643
# 0    0.45357
# Name: target, dtype: float64

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.577383
# 0    0.422617
# Name: target, dtype: float64

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.631627
# 0    0.368373
# Name: target, dtype: float64

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.628563
# 0    0.371437
# Name: target, dtype: float64
