# %%
import pandas as pd; pd.set_option('display.max_columns', 100)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

## Reading data files
train = pd.read_csv('/home/ec2-user/SageMaker/Analytics_Data_Science/House_Prices/Data/train.csv')
test = pd.read_csv('/home/ec2-user/SageMaker/Analytics_Data_Science/House_Prices/Data/test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Visualizations

# %%
plt.hist(train['SalePrice'])
plt.ylabel('Frequency')
plt.xlabel('House Price')
plt.grid()
plt.show()

# %%
plt.scatter(train['YrSold'], train['SalePrice'])
plt.xlabel('Year Sold')
plt.ylabel('House Price')
plt.grid()
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.boxplot(x = 'YrSold', y = 'SalePrice', data = train)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %%
plt.figure(figsize = (15, 10))
sns.boxplot(x = 'MSSubClass', y = 'SalePrice', data = train)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
plt.figure(figsize = (15, 10))
sns.boxplot(x = 'LotConfig', y = 'SalePrice', data = train)
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='SalePrice'>

# %% [markdown]
# ## Feature Engineering

# %%
train['TotalSF'] = train['TotalBsmtSF'] + train['1stFlrSF'] + train['2ndFlrSF'] 
train['TotalBathrooms'] = (train['FullBath'] + (0.5 * train['HalfBath']) + train['BsmtFullBath'] + (0.5 * train['BsmtHalfBath']))
train['PorchSF'] = (train['OpenPorchSF'] + train['3SsnPorch'] + train['EnclosedPorch'] + train['ScreenPorch'] + train['WoodDeckSF'])

train['ExteriorQuality'] = train['ExterQual'] + train['ExterCond']                  
train['BasementQuality'] = (train['BsmtQual'] + train['BsmtCond'] + train['BsmtFinType1'] + train['BsmtFinType2'])
train['GarageQuality'] = train['GarageQual'] + train['GarageCond']                  
train['TotalQuality'] = (train['OverallQual'] + train['ExteriorQuality'] + train['BasementQuality'] + train['GarageQuality'] + train['KitchenQual'] + train['HeatingQC'])
# train['YearBuiltPlusRemodel'] = train['YearBuilt'] + train['YearRemodAdd']          


test['TotalSF'] = test['TotalBsmtSF'] + test['1stFlrSF'] + test['2ndFlrSF'] 
test['TotalBathrooms'] = (test['FullBath'] + (0.5 * test['HalfBath']) + test['BsmtFullBath'] + (0.5 * test['BsmtHalfBath']))
test['PorchSF'] = (test['OpenPorchSF'] + test['3SsnPorch'] + test['EnclosedPorch'] + test['ScreenPorch'] + test['WoodDeckSF'])

# test['ExteriorQuality'] = test['ExterQual'] + test['ExterCond']                  
# test['BasementQuality'] = (test['BsmtQual'] + test['BsmtCond'] + test['BsmtFinType1'] + test['BsmtFinType2'])
# test['GarageQuality'] = test['GarageQual'] + test['GarageCond']                  
# test['TotalQuality'] = (test['OverallQual'] + test['ExteriorQuality'] + test['BasementQuality'] + test['GarageQuality'] + test['KitchenQual'] + test['HeatingQC'])
# test['YearBuiltPlusRemodel'] = test['YearBuilt'] + test['YearRemodAdd']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ...

# %%
train['ExteriorQuality']
# Out:
# 0       GdTA
# 1       TATA
# 2       GdTA
# 3       TATA
# 4       GdTA
#         ...
# 1455    TATA
# 1456    TATA
# 1457    ExGd
# 1458    TATA
# 1459    GdTA
# Name: ExteriorQuality, Length: 1460, dtype: object

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...
